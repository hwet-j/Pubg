# %% [markdown]
# # https://velog.io/@chandni_ml/3.-%EA%B9%83%ED%97%88%EB%B8%8C-%EC%A3%BC%ED%94%BC%ED%84%B0-%EB%85%B8%ED%8A%B8%EB%B6%81-%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4
# ## https://right1203.tistory.com/2 참고
# ## https://developer.pubg.com/ 홈페이지에서 API 등록
#
# #### API에서 사용할  requests, 읽어온 파일 형식이 json
# #### pubg분석에 필요한 라이브러리 chicken_dinner 설치 ( ! 를 기입해주면 프롬프트창에서 명령어 실행)

# %%
# 패키지 불러오기

# api 요청
import requests
import json
# 데이터 자료형 및 분석도구
import pandas as pd
import numpy as np
# 시각화 패키지
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import patheffects

# %matplotlib inline
sns.set()
# 스케일링
from sklearn.preprocessing import MinMaxScaler
# 시간
import time
from datetime import datetime
# 진행 사항 확인
from tqdm import tqdm
# ! pip install chicken_dinner
# PUBG 분석 도구
from chicken_dinner.pubgapi import PUBG
from chicken_dinner.constants import COLORS
from chicken_dinner.constants import map_dimensions

# %%
# api key 설정 및 데이터 요청 (PUBG 홈페이지에 코드 예시 존재)
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI5OTZkYzg3MC04N2M3LTAxM2EtMzVlNC0yMTljOWI0OWJjOGMiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNjQ3NDgzOTk5LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6Imh3ZXQifQ.zN7Z77wEe8Cy2V4nuvEWrSc4rYUVraThjrCN5balzuM'
headers = {'accept': 'application/vnd.api+json',
           'Authorization': f'Bearer {api_key}'}

# 18년도 대회 기록
url = "https://api.pubg.com/tournaments/kr-pkl18"
r = requests.get(url, headers=headers)
league_json = r.json()
# league_json

# %%
# kr-pkl18 데이터 matchId 저장
# 경기ID와 경기날짜를 뽑아내 날짜에 따라 정렬하여 matchId_df에 저장
matchId_dict = {match['attributes']['createdAt']: match['id'] for match in league_json['included']}
matchId_df = pd.DataFrame(sorted(matchId_dict.items(), key=lambda x: x[0]),
                              columns=['createdAt', 'matchId'])

# Rangers 팀이 참가한 데이터만 사용
pubg = PUBG(api_key, shard='tournament')

# GEN_G 게임만 저장
matchId_gen = []

for matchId in tqdm(matchId_df['matchId']):
    # matchId에 해당하는 데이터를 가져옴
    current_match = pubg.match(matchId)
    telemetry = current_match.get_telemetry()
    telemetry.player_names()
    # 플레이어명에 GEN이 포함된 데이터를 찾아 개수를 확인
    findCount = (pd.Series(telemetry.player_names()).str.find('GEN') > -1).sum()
    # 확인한 개수가 1개 이상이면 리스트에 저장
    if findCount > 0:
        matchId_gen.append(matchId)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 107/107 [14:53<00:00,  8.35s/it]

# %%
print(matchId_gen)
# Out:
# ['6188d175-54fa-4d0d-a1d9-932b2fac23ab', 'c3cfe2f2-8746-4faf-ba70-828cf6e19668', 'b335a99f-44b0-47fc-b781-2172eece5593', '93d25bf4-46c3-42e6-88e6-27ec91242647', '0c92a712-45b2-4bb6-af9d-2ae4813eb5fc', '8e48a620-36b1-41f5-9bc5-dd35cfc5ebf0', '04ed8681-1b8a-4aa6-bee6-4a0360ad24ea', '5d975312-d771-4d7f-9de3-039d2a182ef8', '6241c305-35da-4509-8d6c-72268865d914', '57c66676-7282-4840-8b27-44d50313c8aa', '47d1faaa-fdae-4f31-bec0-ebe13b144296', 'a466ff36-c052-4242-92a1-1c07929ffd32', 'aebf2289-0fb2-42b1-8130-dc813eae8256', 'd4dcc5f1-64b2-4b49-84f1-895aaec42929', '1dde4b76-a74e-4456-b3ee-c044468b29e8', 'fae38a34-3ccf-4d86-96e3-d913c4088b20', '83d2a8fc-5f6d-4bc7-b1e6-9fe06a14b66c', 'd0a4e621-d13e-4c04-9fe7-9a2dae50999e', '31dfa5d1-8f04-4d8a-9e9a-bd7eb6dd41a5', 'e18c86a3-a08c-40e8-9cec-4c7274e1722c', '0f3cd866-3c61-4ffc-8857-2c15b58e0de7', 'd8b968c1-eda0-4882-99d9-04d7000c1176', '68d7400f-9885-4fb4-a57b-38bea3bfd389', '40e548ae-8b7e-4851-b789-b8cc6d9fdf00', '87c5e8f6-5fa0-4b38-953f-ab61c2d166dd', '1dd5446b-3bcc-43e5-8a77-5ec12fbe041e', '6678fe52-21a2-498a-9c5d-e9eeb392a26f', 'e306d511-fa81-4eae-9899-51fb40c059ae', '45821922-204d-47bf-aecb-e66920810391', '0b65639d-103c-4c60-96f4-7b9ada93e18a', '1074498c-14ea-4bf8-a389-424eee3d6e3b', '4cf4dc9e-8d82-4801-ad13-688f12d123e9', 'c4873067-9521-4bce-9e19-5d7678c76ef2', '5b7c365c-66e2-453c-a0dd-a1062d8c6882', '94027cf7-38ee-4dcb-b85e-13d5d92e4280', 'bbdfd6ed-bb52-46fc-9d7e-af791fbfbac1', '0e4e7aaa-3b2c-4048-8318-b160e9939769', '1e201544-4d59-4c36-a259-d2529d4c0b6b', '8e6c3701-3cb5-4d0e-96ef-aedaa55b8813', '932da511-6e11-4e7d-8f01-88f9bb208e15', '318052e5-da5e-41ee-8a71-40aabf75a553', '8ce54d9f-1c6b-44f8-bd21-20c314bafc2c', '240fd3df-f410-4a61-8172-1c078a0456a1', '1ba83b28-5d8a-4042-a824-45f694a25059', '7eb3b00b-8321-4605-8991-56835da566ae', 'b63f2031-c72b-4a36-a7bf-783fe6ae525a']

# %%
# 경기 후의 stats 정보를 데이터프레임 안의 데이터프레임으로 저장
# 비효율적. 이번 분석에서는 stats 정보를 이용하지 않았음

# apply lambda를 위한 함수 (시리즈 변환)
def ParticipantsMerge(row):
    participants = pd.Series(row['attributes']['stats'])
    participants['id'] = row['id']
    return participants

headers = {'accept': 'application/vnd.api+json'}

match_df = pd.DataFrame()
participants_df = pd.DataFrame()

# 젠지 경기 하나씩 
for matchId in matchId_gen:
    url = f'https://api.pubg.com/shards/tournament/matches/{matchId}'
    r = requests.get(url, headers=headers)
    while r.status_code != 200:
        time.sleep(2)
        r = requests.get(url, headers=headers)
        
    data = r.json()
    stats_series = pd.Series(data['data']['attributes'])
    stats_series['matchId'] = matchId

    included = pd.DataFrame(data['included'])
    
    rosters = included[included['type'] == 'roster']
    rosters = rosters.apply(lambda row: [row['attributes']['stats']['rank'],
                                         row['attributes']['stats']['teamId'],
                                         row['attributes']['won'],
                                         pd.DataFrame(row['relationships']['participants']['data']),
                                         row['id']], axis=1)
    rosters = pd.DataFrame(list(rosters), columns=['rank', 'teamId', 'won', 'participants', 'id'])

    participants = included[included['type'] == 'participant']
    participants = participants.apply(lambda row: ParticipantsMerge(row), axis=1)
    participants = participants.reset_index(drop=True)
    participants = participants.drop(['killPoints', 'killPointsDelta', 'lastKillPoints', 'lastWinPoints',
                                      'mostDamage', 'rankPoints', 'winPoints', 'winPointsDelta'],
                                      axis=1, errors='ignore')

    rosters['participants'] = rosters['participants'].map(lambda x: x.merge(participants))

    stats_series['rosters'] = rosters

    participants_df = participants_df.append(participants, ignore_index=True, sort=False)
    match_df = match_df.append(stats_series, ignore_index=True, sort=False)

    match_df = match_df.drop(['stats', 'titleId', 'shardId', 'tags', 'gameMode', 'isCustomMatch'], axis=1)

# Erangel 맵 데이터만 사용
erangelMatch_df = match_df[match_df['mapName'] == 'Erangel_Main'].loc[:90]

print(erangelMatch_df)
# Out:
#                createdAt  duration       mapName  \
# 1   2018-10-01T09:56:38Z    1818.0  Erangel_Main
# 2   2018-10-01T10:47:39Z    1612.0  Erangel_Main
# 3   2018-10-01T11:35:35Z    1722.0  Erangel_Main
# 5   2018-10-10T10:05:31Z    1722.0  Erangel_Main
# 6   2018-10-10T10:49:24Z    1782.0  Erangel_Main
# 7   2018-10-10T11:31:53Z    1630.0  Erangel_Main
# 9   2018-10-12T09:51:24Z    1800.0  Erangel_Main
# 10  2018-10-12T10:45:31Z    1671.0  Erangel_Main
# 11  2018-10-12T11:26:03Z    1807.0  Erangel_Main
# 13  2018-10-15T09:59:10Z    1591.0  Erangel_Main
# 14  2018-10-15T10:46:57Z    1834.0  Erangel_Main
# 15  2018-10-15T11:38:49Z    1633.0  Erangel_Main
# 17  2018-10-24T09:52:55Z    1826.0  Erangel_Main
# 18  2018-10-24T10:38:09Z    1621.0  Erangel_Main
# 19  2018-10-24T11:18:20Z    1628.0  Erangel_Main
# 21  2018-10-29T10:00:08Z    1558.0  Erangel_Main
# 22  2018-10-29T10:45:48Z    1746.0  Erangel_Main
# 23  2018-10-29T11:35:08Z    1660.0  Erangel_Main
# 25  2018-11-02T09:54:11Z    1728.0  Erangel_Main
# 26  2018-11-02T10:45:34Z    1719.0  Erangel_Main
# 27  2018-11-02T11:36:14Z    1739.0  Erangel_Main
# 29  2018-11-07T09:46:28Z    1632.0  Erangel_Main
# 30  2018-11-07T10:32:02Z    1579.0  Erangel_Main
# 31  2018-11-07T11:11:41Z    1668.0  Erangel_Main
# 33  2018-11-19T10:33:02Z    1657.0  Erangel_Main
# 34  2018-11-19T11:16:08Z    1591.0  Erangel_Main
# 35  2018-11-19T12:01:03Z    1870.0  Erangel_Main
# 38  2018-11-23T10:15:56Z    1771.0  Erangel_Main
# 39  2018-11-23T11:04:39Z    1754.0  Erangel_Main
# 40  2018-11-23T11:54:53Z    1809.0  Erangel_Main
# 42  2018-12-01T09:31:08Z    1616.0  Erangel_Main
# 43  2018-12-01T10:18:49Z    1697.0  Erangel_Main
# 44  2018-12-01T11:09:27Z    1677.0  Erangel_Main
# 45  2018-12-01T11:55:29Z    1723.0  Erangel_Main
#
#                                  matchId matchType  \
# 1   c3cfe2f2-8746-4faf-ba70-828cf6e19668
# 2   b335a99f-44b0-47fc-b781-2172eece5593
# 3   93d25bf4-46c3-42e6-88e6-27ec91242647
# 5   8e48a620-36b1-41f5-9bc5-dd35cfc5ebf0
# 6   04ed8681-1b8a-4aa6-bee6-4a0360ad24ea
# 7   5d975312-d771-4d7f-9de3-039d2a182ef8
# 9   57c66676-7282-4840-8b27-44d50313c8aa
# 10  47d1faaa-fdae-4f31-bec0-ebe13b144296
# 11  a466ff36-c052-4242-92a1-1c07929ffd32
# 13  d4dcc5f1-64b2-4b49-84f1-895aaec42929
# 14  1dde4b76-a74e-4456-b3ee-c044468b29e8
# 15  fae38a34-3ccf-4d86-96e3-d913c4088b20
# 17  d0a4e621-d13e-4c04-9fe7-9a2dae50999e
# 18  31dfa5d1-8f04-4d8a-9e9a-bd7eb6dd41a5
# 19  e18c86a3-a08c-40e8-9cec-4c7274e1722c
# 21  d8b968c1-eda0-4882-99d9-04d7000c1176
# 22  68d7400f-9885-4fb4-a57b-38bea3bfd389
# 23  40e548ae-8b7e-4851-b789-b8cc6d9fdf00
# 25  1dd5446b-3bcc-43e5-8a77-5ec12fbe041e
# 26  6678fe52-21a2-498a-9c5d-e9eeb392a26f
# 27  e306d511-fa81-4eae-9899-51fb40c059ae
# 29  0b65639d-103c-4c60-96f4-7b9ada93e18a
# 30  1074498c-14ea-4bf8-a389-424eee3d6e3b
# 31  4cf4dc9e-8d82-4801-ad13-688f12d123e9
# 33  5b7c365c-66e2-453c-a0dd-a1062d8c6882
# 34  94027cf7-38ee-4dcb-b85e-13d5d92e4280
# 35  bbdfd6ed-bb52-46fc-9d7e-af791fbfbac1
# 38  8e6c3701-3cb5-4d0e-96ef-aedaa55b8813
# 39  932da511-6e11-4e7d-8f01-88f9bb208e15
# 40  318052e5-da5e-41ee-8a71-40aabf75a553
# 42  240fd3df-f410-4a61-8172-1c078a0456a1
# 43  1ba83b28-5d8a-4042-a824-45f694a25059
# 44  7eb3b00b-8321-4605-8991-56835da566ae
# 45  b63f2031-c72b-4a36-a7bf-783fe6ae525a
#
#                                               rosters seasonState
# 1       rank  teamId    won                       ...
# 2       rank  teamId    won                       ...
# 3       rank  teamId    won                       ...
# 5       rank  teamId    won                       ...    progress
# 6       rank  teamId    won                       ...    progress
# 7       rank  teamId    won                       ...    progress
# 9       rank  teamId    won                       ...    progress
# 10      rank  teamId    won                       ...    progress
# 11      rank  teamId    won                       ...    progress
# 13      rank  teamId    won                       ...    progress
# 14      rank  teamId    won                       ...    progress
# 15      rank  teamId    won                       ...    progress
# 17      rank  teamId    won                       ...    progress
# 18      rank  teamId    won                       ...    progress
# 19      rank  teamId    won                       ...    progress
# 21      rank  teamId    won                       ...    progress
# 22      rank  teamId    won                       ...    progress
# 23      rank  teamId    won                       ...    progress
# 25      rank  teamId    won                       ...    progress
# 26      rank  teamId    won                       ...    progress
# 27      rank  teamId    won                       ...    progress
# 29      rank  teamId    won                       ...    progress
# 30      rank  teamId    won                       ...    progress
# 31      rank  teamId    won                       ...    progress
# 33      rank  teamId    won                       ...    progress
# 34      rank  teamId    won                       ...    progress
# 35      rank  teamId    won                       ...    progress
# 38      rank  teamId    won                       ...    progress
# 39      rank  teamId    won                       ...    progress
# 40      rank  teamId    won                       ...    progress
# 42      rank  teamId    won                       ...    progress
# 43      rank  teamId    won                       ...    progress
# 44      rank  teamId    won                       ...    progress
# 45      rank  teamId    won                       ...    progress

# %%
# 교전 횟수, 첫 차량 탑승, 화이트&블루존과의 상대적 거리 구하기

attack_df = pd.DataFrame()
teamCount = {}
whiteCenter_df = pd.DataFrame()
blueBorder_df = pd.DataFrame()
playerMove_df = pd.DataFrame()
firstVehicle_df = pd.DataFrame()

for matchId in matchId_gen:
    current_match = pubg.match(matchId) #chicken_dinner 라이브러리 이용
    telemetry = current_match.get_telemetry()
    positions = telemetry.player_positions()
    circles = telemetry.circle_positions()
    players = np.array(telemetry.player_names())
    
    # 팀 아이디 (게임당 4명)
    rosters = players[np.where(pd.Series(players).str.find('GEN') > -1)[0]]  # {Team}의 존 상대적 거리
    
    whiteCenter_means = {}
    blueBorder_means = {}
    playerMove_means = {}

    for player in rosters:
        curpos = np.array(positions[player])
        print(curpos)
        while len(circles['white']) < len(curpos): curpos = curpos[:-1]
        length = len(curpos)
        start = np.where(curpos[:, 3] < 30000)[0][0]

        
        curpos = curpos[start:]
        whites = np.array(circles['white'])[start:length]
        blues = np.array(circles['blue'])[start:length]
        white_xDiff = (whites[:, 1] - curpos[:, 1]); white_yDiff = (whites[:, 2] - curpos[:, 2])
        blue_xDiff = (blues[:, 1] - curpos[:, 1]); blue_yDiff = (blues[:, 2] - curpos[:, 2])

        phases = np.where(whites[1:, 4] - whites[:-1, 4] < 0)[0] + 1 # 단계 인덱싱 구하기
        phases = np.append(phases, len(whites))

        white_means = []
        blue_means = []
        moves = []
        pre = 0
        for phase in phases: #단계마다 공식 계산
            cur_white_xDiff = white_xDiff[pre:phase]; cur_white_yDiff = white_yDiff[pre:phase]
            cur_blue_xDiff = blue_xDiff[pre:phase]; cur_blue_yDiff = blue_yDiff[pre:phase]

            whiteCenter_diff = np.sqrt(np.square(cur_white_xDiff) + np.square(cur_white_yDiff)) / whites[pre:phase, 4]
            blueBorder_diff = (blues[pre:phase, 4] - np.sqrt(np.square(cur_blue_xDiff) + np.square(cur_blue_yDiff))) \
                                    / blues[pre:phase, 4]

            white_means.append(whiteCenter_diff.mean())
            blue_means.append(blueBorder_diff.mean())
            moves.append((whiteCenter_diff[1:] - whiteCenter_diff[:-1]).mean())
            pre = phase

        whiteCenter_means[player] = white_means
        blueBorder_means[player] = blue_means
        playerMove_means[player] = moves

    whiteCenter_df = pd.concat(
                        [whiteCenter_df, pd.DataFrame.from_dict(whiteCenter_means, orient='index').T.mean(axis=1)],
                        axis=1, sort=False)
    blueBorder_df = pd.concat(
                        [blueBorder_df, pd.DataFrame.from_dict(blueBorder_means, orient='index').T.mean(axis=1)],
                        axis=1, sort=False)
    playerMove_df = pd.concat(
                        [playerMove_df, pd.DataFrame.from_dict(playerMove_means, orient='index').T.mean(axis=1)],
                        axis=1, sort=False)
'''
    # 게임 시작 시간
    startTime = pd.to_timedelta(telemetry.started()[telemetry.started().find('T')+1:-1])
    endTime = telemetry.events[-1].timestamp # 마지막 이벤트 시간
    endTime = (pd.to_timedelta(endTime[endTime.find('T')+1:-1]) - startTime).total_seconds()
    circles = telemetry.circle_positions()
    whites = np.array(circles['white'])
    phases = np.where(whites[1:, 4] - whites[:-1, 4] != 0)[0] + 1
    phaseTimes = whites[phases, 0]
    phaseTimes = np.append(phaseTimes, endTime)

    attackLog = telemetry.filter_by('log_player_attack') # 교전 (공격한 경우) 데이터
    attackData = [(log['attacker']['name'],
                   (pd.to_timedelta(log.timestamp[log.timestamp.find('T')+1:-1]) - startTime).total_seconds())
                    for log in attackLog if pd.to_timedelta(log.timestamp[log.timestamp.find('T')+1:-1]) > startTime]
    attackData = pd.DataFrame(attackData, columns=['name', 'time'])
    attackData['teamName'] = attackData['name'].str.extract(r'([0-9A-Za-z]+)\_') # 팀명 추출
    attackData['phase'] = np.nan
    for i in range(len(phaseTimes)-1):
        attackData.loc[(attackData['time'] < phaseTimes[i+1]) & (attackData['time'] > phaseTimes[i]), 'phase'] = i+1
    attack_df = pd.concat([attack_df, attackData], axis=0)

    for team in attackData['teamName'].unique():
        try:
            teamCount[team] += 1
        except KeyError:
            teamCount[team] = 1

    vehicles = telemetry.filter_by('log_vehicle_ride') # 차량 탑승 데이터
    firstVehicle = {}
    used_teamId = []
    for vehicle in vehicles: # 팀에서 첫 차량 탑승 경우만 구하기
        if vehicle['vehicle']['vehicle_type'] != 'WheeledVehicle' or \
            vehicle['character']['name'] in firstVehicle.keys() or \
            vehicle['character']['name'][:vehicle['character']['name'].find('_')] in used_teamId: continue
        firstVehicle[vehicle['character']['name'][:vehicle['character']['name'].find('_')]] = \
            ((pd.to_timedelta(vehicle.timestamp[vehicle.timestamp.find('T')+1:-1]) - startTime).total_seconds(), \
            vehicle['character']['location']['x'], mapy - vehicle['character']['location']['y'])
        used_teamId.append(vehicle['character']['name'][:vehicle['character']['name'].find('_')])
    firstVehicle_df = pd.concat([firstVehicle_df, pd.DataFrame(firstVehicle)], axis=1, sort=False)
'''    
    
'''
firstVehicle_df = firstVehicle_df.T
firstVehicle_df.columns = ['time', 'x', 'y']
firstVehicle_df['teamName'] = firstVehicle_df.index
firstVehicle_team = pd.concat([firstVehicle_df[['teamName', 'time']].groupby('teamName').mean(),
                      firstVehicle_df[['teamName', 'time']].groupby('teamName').count()], axis=1, sort=False)
firstVehicle_team.columns = ['time', 'count']
firstVehicle_team = firstVehicle_team[firstVehicle_team['count'] > 10]


# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\chicken_dinner\util.py in camel_to_snake(name)
#       9     try:
# ---> 10         return stats_map[name]
#      11     except KeyError as exc:
#
# KeyError: 'location'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-711b38136c2d> in <module>
#      10 for matchId in matchId_gen:
#      11     current_match = pubg.match(matchId) #chicken_dinner 라이브러리 이용
# ---> 12     telemetry = current_match.get_telemetry()
#      13     positions = telemetry.player_positions()
#      14     circles = telemetry.circle_positions()
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\match\match.py in get_telemetry(self, map_assets)
#     123             for this match.
#     124         """
# --> 125         return Telemetry(self._pubg, self.telemetry_url, shard=self.shard)
#     126
#     127     @property
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\telemetry.py in __init__(self, pubg, url, telemetry_json, shard, map_assets)
#      29             self.response = self._pubg._core.telemetry(url)
#      30         #: Snake cased object-attribute models for telemetry events and objects
# ---> 31         self.events = [TelemetryEvent(e, map_assets) for e in self.response]
#      32         if getattr(self.events[-1], "common", None) is not None:
#      33             #: The platform for this game, "pc" or "xbox"
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\telemetry.py in <listcomp>(.0)
#      29             self.response = self._pubg._core.telemetry(url)
#      30         #: Snake cased object-attribute models for telemetry events and objects
# ---> 31         self.events = [TelemetryEvent(e, map_assets) for e in self.response]
#      32         if getattr(self.events[-1], "common", None) is not None:
#      33             #: The platform for this game, "pc" or "xbox"
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\events.py in __init__(self, data, map_assets)
#      25         for k, v in data.items():
#      26             if isinstance(v, dict):
# ---> 27                 setattr(self, camel_to_snake(k), TelemetryObject(v, k, map_assets))
#      28             elif isinstance(v, list):
#      29                 try:
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\objects.py in __init__(self, data, reference, map_assets)
#      26         for k, v in data.items():
#      27             if isinstance(v, dict):
# ---> 28                 setattr(self, camel_to_snake(k), TelemetryObject(v, k, map_assets))
#      29             elif isinstance(v, list) and len(v) > 0 and isinstance(v[0], dict):
#      30                 setattr(self, camel_to_snake(k), [TelemetryObject(e, k, map_assets) for e in v])
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\models\telemetry\objects.py in __init__(self, data, reference, map_assets)
#      23     def __init__(self, data, reference, map_assets=False):
#      24         #: The key name that references this object
# ---> 25         self.reference = camel_to_snake(reference)
#      26         for k, v in data.items():
#      27             if isinstance(v, dict):
#
# C:\Anaconda3\lib\site-packages\chicken_dinner\util.py in camel_to_snake(name)
#       9     try:
#      10         return stats_map[name]
# ---> 11     except KeyError as exc:
#      12         pass
#      13     s1 = re.sub("(.)([A-Z][a-z]+)", r"\1_\2", name)
#
# KeyboardInterrupt:
